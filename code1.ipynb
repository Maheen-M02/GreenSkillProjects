# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheen-M02/GreenSkillProjects/blob/main/code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter your age: "))
print("Your age is",a)
# Out:
# Enter your age: 19
# Your age is 19

# %%
city_name = "Pune"
print(f"City Name: {city_name}")

city_name = "Nagpur"
print(f"City Name: {city_name}")
# Out:
# City Name: Pune
# City Name: Nagpur

# %%
carbon_footprint = float(input("Enter the value: "))
if(carbon_footprint>400):
  print("It is not sustainable.")

else:
  print(f"Carbon footprint is {carbon_footprint} kg CO2 and is sustainable")
# Out:
# Enter the value: 76
# Carbon footprint is 76.0 kg CO2 and is sustainable

# %%
list1 = [23,45,65,78]
num = int(input("Enter the number: "))
if num in list1:
  print(f"{num} is in the given list")

else:
  print(f"{num} is not in the list.")
# Out:
# Enter the number: 43
# 43 is not in the list.

# %%
num = int(input("Enter the number: "))
if(num%2==0):
  print(f"{num} is even")

else:
  print(f"{num} is odd")
# Out:
# Enter the number: 1
# 1 is odd

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
operator = input("Enter the operator: ")
if(operator=="+"):
  print(f"Addition of {num1} and {num2} is {num1+num2}")
elif(operator=="-"):
  print(f"Subtraction of {num1} and {num2} is {num1-num2}")
elif(operator=="*"):
  print(f"Multiplication of {num1} and {num2} is {num1*num2}")
else:
  print(f"Division of {num1} and {num2} is {num1/num2}")
# Out:
# Enter the first number: 23
# Enter the second number: 23
# Enter the operator: *
# Multiplication of 23 and 23 is 529

# %%
climate_data = [
    {"city": "City A", "temperature": 25, "carbon_footprint": 500},
    {"city": "City B", "temperature": 30, "carbon_footprint": 350},
    {"city": "City C", "temperature": 22, "carbon_footprint": 600},
    {"city": "City D", "temperature": 15, "carbon_footprint": 200},
    {"city": "City E", "temperature": 28, "carbon_footprint": 450},
]

high_temp_threshold = 26
high_temp_cities = [city for city in climate_data if city["temperature"] > high_temp_threshold]

print("Cities with high temperature:")
for city in high_temp_cities:
    print(f"{city['city']} - Temperature: {city['temperature']}°C")
# Out:
# Cities with high temperature:
# City B - Temperature: 30°C
# City E - Temperature: 28°C

# %%
total_carbon_footprint = sum(city["carbon_footprint"] for city in climate_data)
number_of_cities = len(climate_data)
average_carbon_footprint = total_carbon_footprint / number_of_cities

print(f"Average carbon footprint across all cities: {average_carbon_footprint:.2f} kg CO2")
# Out:
# Average carbon footprint across all cities: 420.00 kg CO2

# %%
sustainability_threshold = 400
sustainable_cities = list(filter(lambda city: city["carbon_footprint"]<sustainability_threshold,climate_data))

for city in sustainable_cities:
  print(f"{city['city']} has a carbon footprint below the sustainable threshold.")
# Out:
# City B has a carbon footprint below the sustainable threshold.
# City D has a carbon footprint below the sustainable threshold.

# %%
highest_footprint_city = max(climate_data, key = lambda city: city["carbon_footprint"])
print(f"City with the highest carbon footprint: {highest_footprint_city['city']}")
# Out:
# City with the highest carbon footprint: City C

# %%
def calculate_carbon_footprint(energy_consumption,emission_factor):
  carbon_footprint = energy_consumption*emission_factor
  return carbon_footprint

energy_consumption = float(input("Enter the value of energy consumption: "))
emission_factor = float(input("Enter the value of emission factor: "))
carbon_footprint = calculate_carbon_footprint(energy_consumption,emission_factor)
print(carbon_footprint,"kg CO2")
# Out:
# Enter the value of energy consumption: 234
# Enter the value of emission factor: 323
# 75582.0

# %%
def greet(a):
  print(f"Hello {a}")

a = input("Enter your name: ")
greet(a)
# Out:
# Enter your name: sup
# Hello sup

# %%
list1 = [23,43,57,755,76]
print("Length of the list is",len(list1))
# Out:
# Length of the list is 5

# %%
func = lambda x,y: x*y
print("The product of two numbers is:",func(2,3))
# Out:
# The product of two numbers is: 6

# %%
year  = lambda x: x%4==0
leapyr = int(input("Enter Year: "))
if(year(leapyr)):
  print(f"{leapyr} is a leap year")

else:
  print(f"{leapyr} is not a leap year")
# Out:
# Enter Year: 2000
# 2000 is a leap year

# %%
import pandas as pd

renewable_sources = ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass"]


data = {
    "Project": ["Solar Farm A", "Wind Turbine X", "Hydropower Y", "Solar Roof Z", "Geothermal Plant P"],
    "Technology": ["Solar", "Wind", "Hydropower", "Solar", "Geothermal"],
    "Capacity (MW)": [150, 300, 200, 50, 100],  # Megawatts
    "Cost (Million $)": [200, 400, 350, 100, 250],  # Project cost
    "Location": ["California", "Texas", "Washington", "Nevada", "Idaho"],
    "Completion Year": [2023, 2024, 2022,2025,2023]

}

# %%
renewable_series = pd.Series(renewable_sources)
print(renewable_series)
# Out:
# 0         Solar
# 1          Wind
# 2    Hydropower
# 3    Geothermal
# 4       Biomass
# dtype: object

# %%
projects_df = pd.DataFrame(data)
print("Green technologies")
projects_df.tail()
# Out:
# Green technologies
#               Project  Technology  Capacity (MW)  Cost (Million $)  \
# 0        Solar Farm A       Solar            150               200
# 1      Wind Turbine X        Wind            300               400
# 2        Hydropower Y  Hydropower            200               350
# 3        Solar Roof Z       Solar             50               100
# 4  Geothermal Plant P  Geothermal            100               250
#
#      Location  Completion Year
# 0  California             2023
# 1       Texas             2024
# 2  Washington             2022
# 3      Nevada             2025
# 4       Idaho             2023

# %%
projects_df.describe()
# Out:
#        Capacity (MW)  Cost (Million $)  Completion Year
# count        5.00000          5.000000         5.000000
# mean       160.00000        260.000000      2023.400000
# std         96.17692        119.373364         1.140175
# min         50.00000        100.000000      2022.000000
# 25%        100.00000        200.000000      2023.000000
# 50%        150.00000        250.000000      2023.000000
# 75%        200.00000        350.000000      2024.000000
# max        300.00000        400.000000      2025.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Capacity (MW)'].plot(kind='hist', bins=20, title='Capacity (MW)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Cost (Million $)'].plot(kind='hist', bins=20, title='Cost (Million $)')
# ...

# %%
high_capacity_projects = projects_df[projects_df["Capacity (MW)"]>100]
print("\nProjects with Capactiy Greater that 100 MW: ")
high_capacity_projects
# Out:
# Projects with Capactiy Greater that 100 MW:
#           Project  Technology  Capacity (MW)  Cost (Million $)    Location  \
# 0    Solar Farm A       Solar            150               200  California
# 1  Wind Turbine X        Wind            300               400       Texas
# 2    Hydropower Y  Hydropower            200               350  Washington
#
#    Completion Year  Cost per MW
# 0             2023     1.333333
# 1             2024     1.333333
# 2             2022     1.750000

# %%
projects_df["Cost per MW"] = projects_df["Cost (Million $)"]/projects_df["Capacity (MW)"]
print("\nDataFrame with cost per MW: ")
projects_df
# Out:
# DataFrame with cost per MW:
#               Project  Technology  Capacity (MW)  Cost (Million $)  \
# 0        Solar Farm A       Solar            150               200
# 1      Wind Turbine X        Wind            300               400
# 2        Hydropower Y  Hydropower            200               350
# 3        Solar Roof Z       Solar             50               100
# 4  Geothermal Plant P  Geothermal            100               250
#
#      Location  Completion Year  Cost per MW
# 0  California             2023     1.333333
# 1       Texas             2024     1.333333
# 2  Washington             2022     1.750000
# 3      Nevada             2025     2.000000
# 4       Idaho             2023     2.500000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# projects_df['Capacity (MW)'].plot(kind='hist', bins=20, title='Capacity (MW)')
# ...

# %%
total_capacity = projects_df["Capacity (MW)"].sum()
total_cost = projects_df["Cost (Million $)"].sum()
print("\nTotal Capacity: ",total_capacity,"MW")
print("\nTotal Cost: ",total_cost,"Million $")
# Out:
# Total Capacity:  800 MW
#
# Total Cost:  1300 Million $

# %%
grouped_data = projects_df.groupby("Technology")["Capacity (MW)"].sum()
print("\nTotal Capacity by Technology: ")
grouped_data
# Out:
# Total Capacity by Technology:
# Technology
# Geothermal    100
# Hydropower    200
# Solar         200
# Wind          300
# Name: Capacity (MW), dtype: int64

# %%
import numpy as np
energy_consumption = np.array([1200,3400,2900,1800,2500])
print("Energy Connsumption (in MWh) for different Renewable Sources: ")
print(energy_consumption)
# Out:
# Energy Connsumption (in MWh) for different Renewable Sources:
# [1200 3400 2900 1800 2500]

# %%
print(np.random.rand(5))
# Out:
# [0.82850514 0.61726394 0.22585383 0.28554722 0.5772616 ]

# %%
print(np.random.rand(3,4,5))
# Out:
# [[[0.45849518 0.40802168 0.30236275 0.5893121  0.06500201]
#   [0.94665954 0.3945935  0.38226674 0.14474908 0.25038611]
#   [0.69791214 0.57831161 0.99299306 0.97629734 0.17395542]
#   [0.20849761 0.98605552 0.7880268  0.24834349 0.23133804]]
#
#  [[0.04697348 0.12082008 0.4881513  0.81045483 0.02124337]
#   [0.70138926 0.06061814 0.04553627 0.87569875 0.98147049]
#   [0.63394615 0.96622182 0.71969112 0.7597888  0.29566909]
#   [0.15951374 0.27013596 0.30908502 0.35498583 0.89580086]]
#
#  [[0.14537296 0.50083623 0.05237689 0.71713504 0.19340005]
#   [0.38528221 0.37103401 0.76485977 0.92291858 0.1358209 ]
#   [0.78141213 0.23855752 0.98494888 0.67654947 0.8307768 ]
#   [0.41935198 0.8234817  0.81946406 0.87659384 0.64236101]]]

# %%
total_consumption = np.sum(energy_consumption)
print("Total Energy Consumption: ",total_consumption,"MWh")
# Out:
# Total Energy Consumption:  11800 MWh

# %%
mean_consumption = np.mean(energy_consumption)
print(f"Mean Energy Consumption: {mean_consumption:.2f} MWh")
# Out:
# Mean Energy Consumption: 2360.00 MWh

# %%
reshaped_array = energy_consumption.reshape(5,1)
print("Reshaped Array: ")
print(reshaped_array)
# Out:
# Reshaped Array:
# [[1200]
#  [3400]
#  [2900]
#  [1800]
#  [2500]]

# %%
std_deviation = np.std(energy_consumption)
print(f"Standard Deviation: {std_deviation:.2f} MWh")
# Out:
# Standard Deviation: 781.28 MWh

# %%
import pandas as pd
import numpy as np
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150,250,np.nan]
}

energy_df = pd.DataFrame(data)
energy_df
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
cleaned_df = energy_df.dropna()
print("Cleaned DataFrame:")
cleaned_df.head()
# Out:
# Cleaned DataFrame:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
ec_mean = energy_df["Energy Consumption (MWh)"].mean()
ec_mean = round(ec_mean,2)
print(f"Mean Energy Consumption: {ec_mean} MWh")
cost_mean = energy_df["Cost (Million $)"].mean()
cost_mean = round(cost_mean,2)
print(f"Mean Cost: {cost_mean} Million $")
# Out:
# Mean Energy Consumption: 2450.0 MWh
# Mean Cost: 250.0 Million $

# %%
energy_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0

# %%
forward_filled_df = energy_df.fillna(method="ffill")
print("\nData Before Forward Filling: ")
print(energy_df)
print("\nData After Forward Filling:")
forward_filled_df.head()
# Out:
# Data Before Forward Filling:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
#
# Data After Forward Filling:
# <ipython-input-83-3df7366ad269>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forward_filled_df = energy_df.fillna(method="ffill")
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    1200.0             400.0
# 2    Hydropower                    2900.0             400.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
energy_df["Energy Consumption (MWh)"]=scaler.fit_transform(energy_df[["Energy Consumption (MWh)"]])
energy_df["Cost (Million $)"]=scaler.fit_transform(energy_df[["Cost (Million $)"]])
print("\nNormalized DataFrame:")
energy_df
# Out:
# Normalized DataFrame:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                      0.00               0.2
# 1          Wind                       NaN               1.0
# 2    Hydropower                      0.85               NaN
# 3    Geothermal                       NaN               0.0
# 4       Biomass                      0.65               0.4
# 5       Nuclear                      1.00               NaN

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
energy_df["Energy Consumption (MWh)"]=scaler.fit_transform(energy_df[["Energy Consumption (MWh)"]])
energy_df["Cost (Million $)"]=scaler.fit_transform(energy_df[["Cost (Million $)"]])
print("\nNormalized DataFrame:")
energy_df
# Out:
# Normalized DataFrame:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                 -1.637804         -0.534522
# 1          Wind                       NaN          1.603567
# 2    Hydropower                  0.589610               NaN
# 3    Geothermal                       NaN         -1.069045
# 4       Biomass                  0.065512          0.000000
# 5       Nuclear                  0.982683               NaN

# %%
import matplotlib.pyplot as plt
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
energy_consumption = [1200, 1300, 1100, 1500, 1400, 1600]
plt.plot(months, energy_consumption)
plt.xlabel("Month")
plt.ylabel("Energy Consumption (kWh)")
plt.title("Energy Consumption Over the Year")
plt.show()

# %%
energy_sources = ["Solar", "Wind", "Hydropower", "Biomass"]
energy_values = [1200, 3400, 2900, 2500]
plt.bar(energy_sources, energy_values,color='magenta')
plt.xlabel("Energy Source")
plt.ylabel("Energy Consumption (kWh)")
plt.title("Energy Consumption by Source")
plt.show()

# %%
plt.pie(energy_values,labels=energy_sources,autopct="%1.1f%%")
plt.title("Energy Consumption by Source")
plt.show()

# %%
carbon_emissions = [400,500,450,300,350,550]

plt.scatter(energy_consumption,carbon_emissions,color='cyan')
plt.xlabel("Energy Consumption (kWh)")
plt.ylabel("Carbon Emissions (kg CO2)")
plt.title("Energy Consumption vs Carbon Emissions")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Creating a DataFrame for pair plot
data = {
    "Solar": [1200, 1500, 1300],
    "Wind": [3400, 3600, 3200],
    "Hydropower": [2900, 3100, 2800],
    "Biomass": [2500, 2700, 2400]
}
df = pd.DataFrame(data)
# Create a pair plot
sns.pairplot(df)
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Between Energy Sources')
plt.show()

# %%
sns.boxplot(data=df)
plt.title('Distribution of Energy Consumption by Source')
plt.show()

# %%
sns.violinplot(data=df)
plt.title('Violin Plot of Energy Consumption Distributions')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
energy_values = [100, 200, 300, 400, 500]
carbon_emissions = [10, 20, 25, 40, 50]
df_reg = pd.DataFrame({
    'Energy Consumption': energy_values,
    'Carbon Emissions': carbon_emissions
})
sns.regplot(x='Energy Consumption', y='Carbon Emissions', data=df_reg,color='red')
plt.title('Energy Consumption vs Carbon Emissions')
plt.xlabel('Energy Consumption')
plt.ylabel('Carbon Emissions')
plt.show()
